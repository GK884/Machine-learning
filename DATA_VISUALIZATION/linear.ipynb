# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(2,20,1000)

# %%
m,c=3,10

# %%
y=m*x+c

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
noise=np.random.randn(1000)*5

# %%
y_mod= y + noise

# %%
plt.plot(x,y_mod)

# %%
plt.scatter(x,y_mod)

# %%
x=np.random.randn(1000)

# %%
out=plt.hist(x,bins=120)

# %%
x=np.random.randint(-4,4,1000)

# %%
out=plt.hist(x,bins=120)

# %%
out=plt.pie([10,20,30])

# %%
out=plt.pie([10,20,30] , shadow=True , explode=[0,.1,0],radius=2)

# %%
import seaborn as sns

# %%
x=np.random.randn(1000)
sns.distplot(x)

# %%
#EXPLORE DISTPLOT FUNCTION MORE

# %%
 sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data ['sepal_length'],data['sepal_width'],hue=data['species'])

# %%
#SEABORN IS BASED AND MADE FROM MATPLOTLIB AND YOU CAN USE MATPLOTLIBS FUNC() ON SEABORN

# %%
data=sns.load_dataset('tips')

# %%
data.head()     #for showing data
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data ['total_bill']   #for specific set of data
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.violinplot(x=data.total_bill)

# %%
from sklearn.datasets import load_boston

# %%
X,y=load_boston(return_X_y=True)

# %%
sns.violinplot(y=y)

# %%
sns.boxplot(y=y)
