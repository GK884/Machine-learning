# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil=Image.open("thor.jpg")

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x7F822E238940>

# %%
cut = arr[:5,:5]

# %%
plt.imshow(cut)

# %%
red=arr[: , : , 0 ]

# %%
plt.imshow(red)

# %%
green=arr[:,:,1]

# %%
plt.imshow(green)

# %%
blue=arr[:,:,2]

# %%
plt.imshow(blue)

# %%
green=arr[123:200,:,1]

# %%
plt.imshow(green)

# %%
work=arr.copy()

w2=arr.copy()

# %%
work[:,:,[1,2]]=0

# %%
plt.imshow(work)

# %%
w2[:,:,[0,1]]=0

# %%
plt.imshow(w2)

# %%
gray=work.mean(axis=2)

# %%
plt.imshow(gray,cmap=("gray"))
